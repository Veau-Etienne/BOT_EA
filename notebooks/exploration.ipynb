# %% [markdown]
# # Trading Lab Exploration
#
# Notebook minimal pour charger un export MT5, inspecter les donnees et lancer un backtest depuis Python.

# %%
from pathlib import Path
from src.data.loader import load_mt5_ohlcv

data_path = Path('data/raw/XAUUSD_M15.csv')
data, report = load_mt5_ohlcv(data_path)
report, data.head(), data.tail()
